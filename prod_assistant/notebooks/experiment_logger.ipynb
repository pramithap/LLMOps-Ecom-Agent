# %%
print("all is well")
# Out:
# all is well

# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'c:\\Users\\VPEREPR\\OneDrive - Pearson PLC\\Desktop\\Agentic AI\\LLMOps-ECom-Agent\\prod_assistant\\notebooks'

# %%
#Create a Log Directory
logs_dir = os.path.join(os.getcwd(), "logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
logs_dir
# Out:
# 'c:\\Users\\VPEREPR\\OneDrive - Pearson PLC\\Desktop\\Agentic AI\\LLMOps-ECom-Agent\\prod_assistant\\notebooks\\logs'

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

LOG_FILE
# Out:
# '05_12_2026_13_54_15.log'

# %%
#today
# with today's date log file will be created

#tomorrow
# with tomorrow's date log file will be created

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

LOG_FILE_PATH
# Out:
# 'c:\\Users\\VPEREPR\\OneDrive - Pearson PLC\\Desktop\\Agentic AI\\LLMOps-ECom-Agent\\prod_assistant\\notebooks\\logs\\05_12_2026_13_54_15.log'

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
)

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog
logger = structlog.get_logger()

# %%
logger.info("User uploaded a file", file_name="document.pdf", user_id=12345)
# Out:
# 2026-05-12 13:55:35 [info     ] User uploaded a file           file_name=document.pdf user_id=12345
